# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_user=pd.read_csv(r'C:\Users\mural\Desktop\Projects\Challenge project\challenge_2\relax_challenge\takehome_users.csv',encoding='latin-1')

# %%
df_user.head()
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
# 3          4  2013-05-21 08:09:28    Clausen Nicklas
# 4          5  2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# ...

# %%
df_user_copy=df_user.copy()
df_user_copy.head()
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
# 3          4  2013-05-21 08:09:28    Clausen Nicklas
# 4          5  2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# ...

# %%
df_user_copy['date']=pd.to_datetime(df_user_copy['creation_time'])
df_user_copy=df_user_copy.set_index('date')

# %%
df_user_copy.head()
# Out:
#                      object_id        creation_time               name  \
# date
# 2014-04-22 03:53:30          1  2014-04-22 03:53:30     Clausen August
# 2013-11-15 03:45:04          2  2013-11-15 03:45:04      Poole Matthew
# 2013-03-19 23:14:52          3  2013-03-19 23:14:52  Bottrill Mitchell
# 2013-05-21 08:09:28          4  2013-05-21 08:09:28    Clausen Nicklas
# 2013-01-17 10:14:20          5  2013-01-17 10:14:20          Raw Grace
#
#                                           email creation_source  \
# date
# 2014-04-22 03:53:30    AugustCClausen@yahoo.com    GUEST_INVITE
# 2013-11-15 03:45:04      MatthewPoole@gustr.com      ORG_INVITE
# 2013-03-19 23:14:52  MitchellBottrill@gustr.com      ORG_INVITE
# 2013-05-21 08:09:28   NicklasSClausen@yahoo.com    GUEST_INVITE
# 2013-01-17 10:14:20          GraceRaw@yahoo.com    GUEST_INVITE
#
#                      last_session_creation_time  opted_in_to_mailing_list  \
# date
# ...

# %%
df_user_copy1=set(df_user_copy['creation_time']).intersection(df_user_2['time_stamp'])

# %%
df_user_copy1=[df_user_copy1]
df_user_copy1_df=pd.DataFrame({'common':df_user_copy1})

# %%
df3 = pd.merge(df_user, df_user_2, how='inner', left_on='creation_time', right_on='time_stamp')

# %%
df3 = df3.set_index(['creation_time'])

# %%
df3.index = pd.to_datetime(df3.index)

# %%
df3.head()
# Out:
#                      object_id               name  \
# creation_time
# 2014-04-22 03:53:30          1     Clausen August
# 2013-11-15 03:45:04          2      Poole Matthew
# 2013-03-19 23:14:52          3  Bottrill Mitchell
# 2013-01-16 22:08:03         10       Santos Carla
# 2014-03-30 16:19:38         13      Fry Alexander
#
#                                              email creation_source  \
# creation_time
# 2014-04-22 03:53:30       AugustCClausen@yahoo.com    GUEST_INVITE
# 2013-11-15 03:45:04         MatthewPoole@gustr.com      ORG_INVITE
# 2013-03-19 23:14:52     MitchellBottrill@gustr.com      ORG_INVITE
# 2013-01-16 22:08:03  CarlaFerreiraSantos@gustr.com      ORG_INVITE
# 2014-03-30 16:19:38         AlexanderDFry@cuvox.de      ORG_INVITE
#
#                      last_session_creation_time  opted_in_to_mailing_list  \
# creation_time
# 2014-04-22 03:53:30                1.398139e+09                         1
# ...

# %%
pd.Grouper(level='creation_time',freq='W')
df3.resample('W', on='creation_time').price.sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-6d5c0e7fc56a> in <module>
#       1 pd.Grouper(level='creation_time',freq='W')
# ----> 2 df3.resample('W', on='creation_time').price.sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level)
#    8102
#    8103         axis = self._get_axis_number(axis)
# -> 8104         return resample(
#    8105             self,
#    8106             freq=rule,
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1268     """
#    1269     tg = TimeGrouper(**kwds)
# -> 1270     return tg._get_resampler(obj, kind=kind)
#    1271
#    1272
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1391
#    1392         """
# ...

# %%
df3.shape
# Out:
# (4395, 13)

# %%
df3.head()
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
# 3         10  2013-01-16 22:08:03       Santos Carla
# 4         13  2014-03-30 16:19:38      Fry Alexander
#
#                            email creation_source  last_session_creation_time  \
# 0       AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1         MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2     MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3  CarlaFerreiraSantos@gustr.com      ORG_INVITE                1.401833e+09
# 4         AlexanderDFry@cuvox.de      ORG_INVITE                1.396196e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# ...

# %%
df2 = df3.set_index(['creation_time'])
df2.index = pd.to_datetime(df2.index, unit=None)

# %%
# df2.resample('W',on=df2.index).visited.sum() -Mon

df3.groupby('visited').resample('W', on='creation_time').sum().reset_index().sort_values(by='creation_time')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-089a2dfbecbf> in <module>
#       1 # df2.resample('W',on=df2.index).visited.sum() -Mon
#       2
# ----> 3 df3.groupby('visited').resample('W', on='creation_time').sum().reset_index().sort_values(by='creation_time')
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in resample(self, rule, *args, **kwargs)
#    1557         from pandas.core.resample import get_resampler_for_grouping
#    1558
# -> 1559         return get_resampler_for_grouping(self, rule, *args, **kwargs)
#    1560
#    1561     @Substitution(name="groupby")
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in get_resampler_for_grouping(groupby, rule, how, fill_method, limit, kind, **kwargs)
#    1285
#    1286     tg = TimeGrouper(freq=rule, **kwargs)
# -> 1287     resampler = tg._get_resampler(groupby.obj, kind=kind)
# ...

# %%
df_user_2=pd.read_csv(r'C:\Users\mural\Desktop\Projects\Challenge project\challenge_2\relax_challenge\takehome_user_engagement.csv',encoding='latin-1')

# %%
df_user_2.head()
# Out:
#             time_stamp  user_id  visited
# 0  2014-04-22 03:53:30        1        1
# 1  2013-11-15 03:45:04        2        1
# 2  2013-11-29 03:45:04        2        1
# 3  2013-12-09 03:45:04        2        1
# 4  2013-12-25 03:45:04        2        1

# %%
df_user.columns
# Out:
# Index(['object_id', 'creation_time', 'name', 'email', 'creation_source',
#        'last_session_creation_time', 'opted_in_to_mailing_list',
#        'enabled_for_marketing_drip', 'org_id', 'invited_by_user_id'],
#       dtype='object')

# %%
df_user_2.shape
# Out:
# (207917, 3)

# %%
df_user.shape
# Out:
# (12000, 10)
